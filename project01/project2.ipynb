# %%
import pyswarms as ps
import numpy as np
from pyswarms.utils.plotters import plot_cost_history
import matplotlib.pyplot as plt
import time

# %%
n = 8

def createBoard(n: int) -> list[list[int]]:
    return np.zeros((n, n), dtype=int)

def fulfillBoard(solution: list[int]) -> list[list[int]]:
    board = createBoard(n)
    
    for i in range(len(solution)):
        x = solution[i]
        board[i][x] = 1

    return board

def checkColission(row: int, col: int, board: list[list[int]]) -> bool:
    n = len(board)
    
    # Check row and column
    if sum(board[row]) > 1 or sum([board[i][col] for i in range(n)]) > 1:
        return True
    
    # Check diagonal
    for i, j in zip(range(row, -1, -1), range(col, -1, -1)):
        if board[i][j] == 1 and (i, j) != (row, col):
            return True
    for i, j in zip(range(row, n), range(col, -1, -1)):
        if board[i][j] == 1 and (i, j) != (row, col):
            return True
    
    return False

def fitness_func(solution):
    newSol = solution.astype(int)
    attacks = 0
    board = fulfillBoard(newSol)

    for i in range(len(board)):
        for j in range(len(board[i])):
            if board[i][j] == 1:
                if checkColission(i, j, board):
                    attacks += 1
                    
    board = createBoard(n)
    return (attacks * -1)

# %%
def f(x):
    n_particles = x.shape[0]
    j = [-fitness_func(x[i]) for i in range(n_particles)]
    return np.array(j).astype(int)

# %%
def generate_optimizer(n):
    options = {'c1': 0.5, 'c2': 0.3, 'w':0.9}

    x_max = np.full((n,), n)
    x_min = np.zeros(n)
    my_bounds = (x_min, x_max)

    return ps.single.GlobalBestPSO(n_particles=20, dimensions=n,
    options=options, bounds=my_bounds)

# %%
n = 1
optimizer = generate_optimizer(n)
optimizer.optimize(f, iters=1000)
cost_history = optimizer.cost_history
plot_cost_history(cost_history)
plt.show()
# Out:
# 2023-04-07 17:16:16,387 - pyswarms.single.global_best - INFO - Optimize for 1000 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|██████████|1000/1000, best_cost=0
# 2023-04-07 17:16:20,251 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [0.47143928]

# %%
n = 2
optimizer = generate_optimizer(n)
optimizer.optimize(f, iters=1000)
cost_history = optimizer.cost_history
plot_cost_history(cost_history)
plt.show()
# Out:
# 2023-04-07 16:56:59,041 - pyswarms.single.global_best - INFO - Optimize for 1000 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|██████████|1000/1000, best_cost=1
# 2023-04-07 16:57:03,179 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 1.0, best pos: [1.0013856  0.93818835]

# %%
n = 5
optimizer = generate_optimizer(n)
optimizer.optimize(f, iters=1000)
cost_history = optimizer.cost_history
plot_cost_history(cost_history)
plt.show()
# Out:
# 2023-04-07 16:57:03,638 - pyswarms.single.global_best - INFO - Optimize for 1000 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|██████████|1000/1000, best_cost=0
# 2023-04-07 16:57:08,710 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [1.94534044 3.68229057 0.11547343 2.76401835 4.6976728 ]

# %%
n = 7
optimizer = generate_optimizer(n)
optimizer.optimize(f, iters=1000)
cost_history = optimizer.cost_history
plot_cost_history(cost_history)
plt.show()
# Out:
# 2023-04-07 16:57:09,392 - pyswarms.single.global_best - INFO - Optimize for 1000 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|██████████|1000/1000, best_cost=0
# 2023-04-07 16:57:16,602 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [3.43253259 0.7782319  2.5541872  5.75159347 1.67240548 6.04854445
#  4.94962269]

# %%
n = 8
optimizer = generate_optimizer(n)
optimizer.optimize(f, iters=1000)
cost_history = optimizer.cost_history
plot_cost_history(cost_history)
plt.show()
# Out:
# 2023-04-07 17:05:12,151 - pyswarms.single.global_best - INFO - Optimize for 1000 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|██████████|1000/1000, best_cost=0
# 2023-04-07 17:05:20,051 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [3.26087723 7.22257056 0.59616481 4.64284533 6.58341638 1.0065267
#  5.9879159  2.92138901]

# %%
n = 9
optimizer = generate_optimizer(n)
optimizer.optimize(f, iters=1000)
cost_history = optimizer.cost_history
plot_cost_history(cost_history)
plt.show()
# Out:
# 2023-04-07 17:00:19,706 - pyswarms.single.global_best - INFO - Optimize for 1000 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|██████████|1000/1000, best_cost=0
# 2023-04-07 17:00:28,014 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [1.03875367 6.1566388  4.16599541 0.84905478 8.68339912 3.99456748
#  5.94107784 7.26992055 2.48685877]

# %%
n = 12
optimizer = generate_optimizer(n)
optimizer.optimize(f, iters=1000)
cost_history = optimizer.cost_history
plot_cost_history(cost_history)
plt.show()
# Out:
# 2023-04-07 16:57:33,102 - pyswarms.single.global_best - INFO - Optimize for 1000 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|██████████|1000/1000, best_cost=3
# 2023-04-07 16:57:44,199 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 3.0, best pos: [ 6.39646852  6.90215698  9.09504884  3.55736476  6.03650827  4.17163256
#   1.46485468  8.8654273  11.16132955  5.75036343  7.65591326  2.77934495]

# %%
n = 13
optimizer = generate_optimizer(n)
optimizer.optimize(f, iters=1000)
cost_history = optimizer.cost_history
plot_cost_history(cost_history)
plt.show()
# Out:
# 2023-04-07 16:57:44,872 - pyswarms.single.global_best - INFO - Optimize for 1000 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|██████████|1000/1000, best_cost=3
# 2023-04-07 16:57:56,774 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 3.0, best pos: [11.16668539  4.62934499  5.11539717  1.23711896  6.17418229  9.16739134
#  12.5683861   8.34909692  0.83448388  3.73322732  7.34596849 10.39242046
#  10.17763039]

# %%
n = 15
optimizer = generate_optimizer(n)
optimizer.optimize(f, iters=1000)
cost_history = optimizer.cost_history
plot_cost_history(cost_history)
plt.show()
# Out:
# 2023-04-07 16:57:57,339 - pyswarms.single.global_best - INFO - Optimize for 1000 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|██████████|1000/1000, best_cost=4
# 2023-04-07 16:58:11,238 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 4.0, best pos: [ 8.51442221  5.10605817  7.66348016 10.72436949  2.19077523  4.13417364
#   5.81328136  9.70692229  3.81223208  1.15099351 13.61089446 11.51397622
#   6.87116151 14.21575987  5.69008934]

# %%
def printAverages(times, solved):
    average_time = 0
    for time in times:
        average_time += time
    average_time = average_time / len(times)
    print("Average time (sec): ", average_time)

    print(f"PSO solved {solved}/100")

# %%
n = 5

times = []
generations = []
solved = 0
for i in range(100):
    start = time.time()
    optimizer = generate_optimizer(n)
    
    cost, _ = optimizer.optimize(f, iters=200)
    end = time.time()
    times.append(end - start)
    
    if cost == 0.0:
        solved += 1
    
printAverages(times, solved)
# Out:
# 2023-04-07 17:35:44,276 - pyswarms.single.global_best - INFO - Optimize for 200 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9, 'verbose': False}
# pyswarms.single.global_best: 100%|██████████|200/200, best_cost=0
# 2023-04-07 17:35:45,312 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [2.88620685 0.80281614 3.82733707 1.49846442 4.06125682]
# 2023-04-07 17:35:45,332 - pyswarms.single.global_best - INFO - Optimize for 200 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9, 'verbose': False}
# pyswarms.single.global_best: 100%|██████████|200/200, best_cost=0
# 2023-04-07 17:35:46,275 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [0.88458159 2.17556063 4.27921067 1.26581043 3.06018369]
# 2023-04-07 17:35:46,298 - pyswarms.single.global_best - INFO - Optimize for 200 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9, 'verbose': False}
# pyswarms.single.global_best: 100%|██████████|200/200, best_cost=0
# 2023-04-07 17:35:47,254 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [3.07269776 0.8226046  2.79182896 4.94364335 1.97962282]
# 2023-04-07 17:35:47,270 - pyswarms.single.global_best - INFO - Optimize for 200 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9, 'verbose': False}
# pyswarms.single.global_best: 100%|██████████|200/200, best_cost=0
# 2023-04-07 17:35:48,237 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [0.33508148 2.00455523 4.43579308 1.97201624 3.40269268]
# 2023-04-07 17:35:48,259 - pyswarms.single.global_best - INFO - Optimize for 200 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9, 'verbose': False}
# pyswarms.single.global_best: 100%|██████████|200/200, best_cost=0
# 2023-04-07 17:35:49,189 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [0.5379537  2.7174716  4.15361537 1.09212401 3.68173478]
# 2023-04-07 17:35:49,208 - pyswarms.single.global_best - INFO - Optimize for 200 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9, 'verbose': False}
# pyswarms.single.global_best: 100%|██████████|200/200, best_cost=0
# 2023-04-07 17:35:50,203 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [0.69675558 2.63096721 4.5463902  1.51382077 3.6357883 ]
# 2023-04-07 17:35:50,219 - pyswarms.single.global_best - INFO - Optimize for 200 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9, 'verbose': False}
# pyswarms.single.global_best: 100%|██████████|200/200, best_cost=0
# 2023-04-07 17:35:51,211 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [4.9675692  2.41934783 0.48454314 3.19222841 1.57196219]
# 2023-04-07 17:35:51,225 - pyswarms.single.global_best - INFO - Optimize for 200 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9, 'verbose': False}
# pyswarms.single.global_best: 100%|██████████|200/200, best_cost=0
# 2023-04-07 17:35:52,117 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [2.22352871 0.5643062  3.51840821 1.31121528 4.18269678]
# 2023-04-07 17:35:52,134 - pyswarms.single.global_best - INFO - Optimize for 200 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9, 'verbose': False}
# pyswarms.single.global_best: 100%|██████████|200/200, best_cost=0
# 2023-04-07 17:35:53,062 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [0.2848215  3.47221656 1.02615546 4.17099381 2.44065536]
# 2023-04-07 17:35:53,082 - pyswarms.single.global_best - INFO - Optimize for 200 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9, 'verbose': False}
# pyswarms.single.global_best: 100%|██████████|200/200, best_cost=0
# 2023-04-07 17:35:54,040 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [1.34135427 4.20456808 2.74082541 0.12395585 3.185401  ]
# 2023-04-07 17:35:54,057 - pyswarms.single.global_best - INFO - Optimize for 200 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9, 'verbose': False}
# pyswarms.single.global_best: 100%|██████████|200/200, best_cost=0
# 2023-04-07 17:35:55,039 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [1.47821949 3.03667514 0.25108699 2.91956143 4.48429337]
# 2023-04-07 17:35:55,059 - pyswarms.single.global_best - INFO - Optimize for 200 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9, 'verbose': False}
# pyswarms.single.global_best: 100%|██████████|200/200, best_cost=0
# 2023-04-07 17:35:56,014 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [4.26601172 1.39096147 3.68631963 0.23816338 2.32674262]
# 2023-04-07 17:35:56,031 - pyswarms.single.global_best - INFO - Optimize for 200 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9, 'verbose': False}
# pyswarms.single.global_best: 100%|██████████|200/200, best_cost=0
# 2023-04-07 17:35:57,001 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [4.31440948 1.48587085 3.76305464 0.88225824 2.73118141]
# 2023-04-07 17:35:57,016 - pyswarms.single.global_best - INFO - Optimize for 200 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9, 'verbose': False}
# pyswarms.single.global_best: 100%|██████████|200/200, best_cost=0
# 2023-04-07 17:35:57,988 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [3.12719051 0.96569658 2.02974251 4.60264808 1.10221008]
# 2023-04-07 17:35:58,004 - pyswarms.single.global_best - INFO - Optimize for 200 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9, 'verbose': False}
# pyswarms.single.global_best: 100%|██████████|200/200, best_cost=0
# 2023-04-07 17:35:58,963 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [2.75339271 4.16037274 1.66749792 3.88328714 0.10982706]
# 2023-04-07 17:35:58,989 - pyswarms.single.global_best - INFO - Optimize for 200 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9, 'verbose': False}
# pyswarms.single.global_best: 100%|██████████|200/200, best_cost=0
# 2023-04-07 17:35:59,932 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [1.88814978 4.69998713 2.35876821 0.19694943 3.57022114]
# 2023-04-07 17:35:59,953 - pyswarms.single.global_best - INFO - Optimize for 200 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9, 'verbose': False}
# pyswarms.single.global_best: 100%|██████████|200/200, best_cost=0
# 2023-04-07 17:36:00,892 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [2.54501133e+00 4.43491569e+00 1.76057594e+00 3.21686338e+00
#  1.87727812e-03]
# 2023-04-07 17:36:00,903 - pyswarms.single.global_best - INFO - Optimize for 200 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9, 'verbose': False}
# pyswarms.single.global_best: 100%|██████████|200/200, best_cost=0
# 2023-04-07 17:36:01,855 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [0.5645714  2.35851436 4.11860615 1.99546924 3.44292226]
# 2023-04-07 17:36:01,874 - pyswarms.single.global_best - INFO - Optimize for 200 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9, 'verbose': False}
# pyswarms.single.global_best: 100%|██████████|200/200, best_cost=0
# 2023-04-07 17:36:02,798 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [3.19428114 1.12420874 4.17947017 2.67570989 0.69911466]
# 2023-04-07 17:36:02,813 - pyswarms.single.global_best - INFO - Optimize for 200 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9, 'verbose': False}
# pyswarms.single.global_best: 100%|██████████|200/200, best_cost=0
# 2023-04-07 17:36:03,770 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0, best pos: [1.54305021 4.03525746 2.58370854 0.4934374  3.13059422]
# 2023-04-07 17:36:03,790 - pyswarms.single.global_best - INFO - Optimize for 200 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9, 'verbose': False}
# pyswarms.single.global_best: 100%|██████████|200/200, best_cost=0
# 2023-04-07 17:36