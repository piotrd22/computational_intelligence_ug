# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv("diabetes.csv")
df
# Out:
#      pregnant-times  glucose-concentr  blood-pressure  skin-thickness  \
# 0                 6               148              72              35
# 1                 1                85              66              29
# 2                 8               183              64               0
# 3                 1                89              66              23
# 4                 0               137              40              35
# ..              ...               ...             ...             ...
# 763              10               101              76              48
# 764               2               122              70              27
# 765               5               121              72              23
# 766               1               126              60               0
# 767               1                93              70              31
#
#      insulin  mass-index  pedigree-func  age            class
# 0          0        33.6          0.627   50  tested_positive
# 1          0        26.6          0.351   31  tested_negative
# 2          0        23.3          0.672   32  tested_positive
# 3         94        28.1          0.167   21  tested_negative
# 4        168        43.1          2.288   33  tested_positive
# ..       ...         ...            ...  ...              ...
# 763      180        32.9          0.171   63  tested_negative
# 764        0        36.8          0.340   27  tested_negative
# 765      112        26.2          0.245   30  tested_negative
# 766        0        30.1          0.349   47  tested_positive
# 767        0        30.4          0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
classes = df[['class']].replace(["tested_negative", "tested_positive"], [0, 1])

values = df.values[:, 0:8]
labels = classes.values

(train_values, test_values, train_label, test_label) = train_test_split(values, labels, train_size=0.7)

# %%
mlp = MLPClassifier(solver='lbfgs', activation='relu', alpha=1e-5, hidden_layer_sizes=(6, 3), random_state=1, max_iter=500)

mlp.fit(train_values, train_label.ravel()) 

predictions_train = mlp.predict(train_values)
predictions_test = mlp.predict(test_values)

print("Accuracy on train data set: ", accuracy_score(predictions_train, train_label))
print("Accuracy on test data set: ", accuracy_score(predictions_test, test_label))
# Out:
# Accuracy on train data set:  0.7411545623836127
# Accuracy on test data set:  0.6406926406926406

# %%
confusion_matrix(test_label, predictions_test)
# Out:
# array([[113,  44],
#        [ 39,  35]], dtype=int64)
